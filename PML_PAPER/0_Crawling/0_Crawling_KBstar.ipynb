# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# ## Review crawling

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.kbstar.kbbank',
    sleep_milliseconds=0, # defaults to 0
    lang='ko', # defaults to 'en'
    country='kr', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # dafaults to Sort.MOST_RELEVANT
    filter_score_with=None
)

# %%
import pandas as pd
df = pd.DataFrame(result)

# %%
rev_df = df[['reviewId', 'content', 'score', 'thumbsUpCount', 'at', 'appVersion']]

# %%
rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69611 entries, 0 to 69610
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       69611 non-null  object
#  1   content        69555 non-null  object
#  2   score          69611 non-null  int64
#  3   thumbsUpCount  69611 non-null  int64
#  4   at             69611 non-null  datetime64[ns]
#  5   appVersion     65264 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 3.2+ MB

# %% [markdown]
# The content and appVersion columns contain null values.

# %%
rev_df['content'].isnull().sum()
# Out:
# 56

# %%
# Remove rows with empty content
del_rev_df = rev_df.dropna(subset=['content'])
len(del_rev_df)
# Out:
# 69555

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Save as a CSV file.
# To ensure that Korean characters are saved correctly, you need to add encoding='utf8'.
del_rev_df.to_csv("/content/drive/MyDrive/PML_PAPRER/0_Crawling/0_CrawlingData/03_Crawling_KBstar.csv", encoding='utf8', index=False,escapechar='\\')
