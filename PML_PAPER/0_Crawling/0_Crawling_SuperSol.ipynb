# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Review crawling

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.shinhan.smartcaremgr',
    sleep_milliseconds=0, # defaults to 0
    lang='ko', # defaults to 'en'
    country='kr', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # dafaults to Sort.MOST_RELEVANT
    filter_score_with=None
)

# %%
import pandas as pd
df = pd.DataFrame(result)

# %%
rev_df = df[['reviewId', 'content', 'score', 'thumbsUpCount', 'at', 'appVersion']]

# %%
df
# Out:
#                                   reviewId    userName  \
# 0     f1f9da7d-c7fa-470f-b5b4-a7898fb40da4  Google 사용자
# 1     2f74fbbb-d162-4c32-b150-f7c49e495789  Google 사용자
# 2     cdce194f-a65c-41ed-8135-1782ef63f3ae  Google 사용자
# 3     e01db796-e9ea-4153-a572-df8464c7d395  Google 사용자
# 4     4cf61aab-e157-43e5-9dc6-41647cc5ff70  Google 사용자
# ...                                    ...         ...
# 7337  47574dea-9ee3-451a-ada2-62d80c74d102  Google 사용자
# 7338  9120576d-5bf1-48e4-89f9-f8bea6d900e8  Google 사용자
# 7339  bb9ec82f-2061-4a19-af2d-85f52b8bf796  Google 사용자
# 7340  c5b6d3e9-65c0-4cf3-98e1-eb788673b550  Google 사용자
# 7341  9c1a32a6-88cf-4946-aa4c-1d71b700e371  Google 사용자
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
rev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7342 entries, 0 to 7341
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       7342 non-null   object
#  1   content        7301 non-null   object
#  2   score          7342 non-null   int64
#  3   thumbsUpCount  7342 non-null   int64
#  4   at             7342 non-null   datetime64[ns]
#  5   appVersion     6699 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 344.3+ KB

# %% [markdown]
# The content and appVersion columns contain null values.

# %%
rev_df['content'].isnull().sum()
# Out:
# 41

# %%
# Remove rows with empty content
del_rev_df = rev_df.dropna(subset=['content'])
len(del_rev_df)
# Out:
# 7246

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Save as a CSV file.
# To ensure that Korean characters are saved correctly, you need to add encoding='utf8'.
del_rev_df.to_csv("/content/drive/MyDrive/PML_PAPRER/0_Crawling/0_CrawlingData/01_Crawling_SuperSol.csv", encoding='utf8', index=False,escapechar='\\')
